# %%
import pandas as pd

pd.read_xml('/content/clashresults.xml')
# Out:
#          name                                  guid  \
# 0    Clash623  acc45b46-234e-48db-a1ee-3a2d812690c8
# 1    Clash624  3cf6e5d2-f4a8-437d-8759-ad71d0adc5ea
# 2    Clash625  0c1549cb-83c7-4b27-893c-7c647afe9017
# 3    Clash626  51e482da-60bb-48a8-a6de-027c8e06b391
# 4    Clash627  fc8ff739-6840-401f-9b4c-9c36fefcba57
# ..        ...                                   ...
# 100  Clash524  586d3d0f-c296-4d58-943b-2ee7646af5b6
# 101  Clash576  2c88a67d-d2ec-442a-a9c3-98f7dab4cc54
# 102  Clash527  095e4b0a-c83b-4e3a-91e2-b10491af7410
# 103  Clash579  0545f146-c2df-4f4d-939c-c2f4b47fc653
# 104  Clash622  3913a346-1a76-45b3-ae17-5efc60ea2ae4
#
#                                                   href  status  distance  \
# 0    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new    -0.126
# 1    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new    -0.122
# 2    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new    -0.109
# ...

# %%
import pandas as pd
import xml.etree.ElementTree as ET

# %%
#parsing xml data
tree = ET.parse('/content/clashresults.xml')

root = tree.getroot()

# %%
#initialising data
data = []

# %%
def parse_element(element, item):
  if len(list(element)) == 0:
    item[element.tag] = element.text

  else:
    for child in list(element):
      parse_element(child, item)
      if len(list(child)) == 0:
        item[child.tag] = child.text

# %%
for child in root:
  item = {}
  parse_element(child, item)
  data.append(item)

# %%
data
# Out:
# [{'description': 'Hard',
#   'resultstatus': 'New',
#   'pos3f': None,
#   'gridlocation': 'Xb2-Yb7 : 基礎梁底',
#   'date': None,
#   'name': 'Item Type',
#   'value': 'Solid'},
#  {'description': 'Hard',
#   'resultstatus': 'New',
#   'pos3f': None,
#   'gridlocation': 'Xb2-Yb7 : 基礎梁底',
#   'date': None,
#   'name': 'Item Type',
#   'value': 'Solid'},
#  {'description': 'Hard',
#   'resultstatus': 'New',
#   'pos3f': None,
#   'gridlocation': 'Xb2-Yb7 : 基礎梁底',
#   'date': None,
#   'name': 'Item Type',
#   'value': 'Solid'},
#  {'description': 'Hard',
#   'resultstatus': 'New',
#   'pos3f': None,
#   'gridlocation': 'Xb2-Yb7 : 基礎梁底',
#   'date': None,
#   'name': 'Item Type',
#   'value': 'Solid'},
#  {'description': 'Hard',
#   'resultstatus': 'New',
#   'pos3f': None,
#   'gridlocation': 'Xb2-Yb7 : 基礎梁底',
#   'date': None,
#   'name': 'Item Type',
#   'value': 'Solid'},
#  {'description': 'Hard',
#   'resultstatus': 'New',
#   'pos3f': None,
#   'gridlocation': 'Xb2-Yb7 : 基礎梁底',
# ...

# %%
pd.read_xml('/content/clashresults.xml')
# Out:
#          name                                  guid  \
# 0    Clash623  acc45b46-234e-48db-a1ee-3a2d812690c8
# 1    Clash624  3cf6e5d2-f4a8-437d-8759-ad71d0adc5ea
# 2    Clash625  0c1549cb-83c7-4b27-893c-7c647afe9017
# 3    Clash626  51e482da-60bb-48a8-a6de-027c8e06b391
# 4    Clash627  fc8ff739-6840-401f-9b4c-9c36fefcba57
# ..        ...                                   ...
# 100  Clash524  586d3d0f-c296-4d58-943b-2ee7646af5b6
# 101  Clash576  2c88a67d-d2ec-442a-a9c3-98f7dab4cc54
# 102  Clash527  095e4b0a-c83b-4e3a-91e2-b10491af7410
# 103  Clash579  0545f146-c2df-4f4d-939c-c2f4b47fc653
# 104  Clash622  3913a346-1a76-45b3-ae17-5efc60ea2ae4
#
#                                                   href  status  distance  \
# 0    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new    -0.126
# 1    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new    -0.122
# 2    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new    -0.109
# ...

# %%
import xml.etree.ElementTree as et
from collections import defaultdict
import pandas as pd


def flatten_xml(node, key_prefix=()):
    """
    Walk an XML node, generating tuples of key parts and values.
    """

    # Copy tag content if any
    text = (node.text or '').strip()
    if text:
        yield key_prefix, text

    # Copy attributes
    for attr, value in node.items():
        yield key_prefix + (attr,), value

    # Recurse into children
    for child in node:
        yield from flatten_xml(child, key_prefix + (child.tag,))


def dictify_key_pairs(pairs, key_sep='-'):
    """
    Dictify key pairs from flatten_xml, taking care of duplicate keys.
    """
    out = {}

    # Group by candidate key.
    key_map = defaultdict(list)
    for key_parts, value in pairs:
        key_map[key_sep.join(key_parts)].append(value)

    # Figure out the final dict with suffixes if required.
    for key, values in key_map.items():
        if len(values) == 1:  # No need to suffix keys.
            out[key] = values[0]
        else:  # More than one value for this key.
            for suffix, value in enumerate(values, 1):
                out[f'{key}{key_sep}{suffix}'] = value

    return out

# %%
# Parse XML with etree
tree = et.XML("""<clashresults>
          <clashresult name="Clash623" guid="acc45b46-234e-48db-a1ee-3a2d812690c8" href="L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulations vs M_03_Ducts,Duct Fittings,Duct Insulations,Duct Linings_files\cd37510001.jpg" status="new" distance="-0.126">
            <description>Hard</description>
            <resultstatus>New</resultstatus>
            <clashpoint>
              <pos3f x="20589.937" y="-24498.443" z="55.037"/>
            </clashpoint>
            <gridlocation>Xb2-Yb7 : 基礎梁底</gridlocation>
            <createddate>
              <date year="2025" month="7" day="18" hour="16" minute="11" second="27"/>
            </createddate>
            <clashobjects>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>25672497</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>PH - Sanitary - Vent</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>27615688</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>NSI-Ventilation - Extract Air - Smoke</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
            </clashobjects>
          </clashresult>
          <clashresult name="Clash624" guid="3cf6e5d2-f4a8-437d-8759-ad71d0adc5ea" href="L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulations vs M_03_Ducts,Duct Fittings,Duct Insulations,Duct Linings_files\cd37510002.jpg" status="new" distance="-0.122">
            <description>Hard</description>
            <resultstatus>New</resultstatus>
            <clashpoint>
              <pos3f x="20589.937" y="-24498.443" z="55.033"/>
            </clashpoint>
            <gridlocation>Xb2-Yb7 : 基礎梁底</gridlocation>
            <createddate>
              <date year="2025" month="7" day="18" hour="16" minute="11" second="27"/>
            </createddate>
            <clashobjects>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>25672497</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>PH - Sanitary - Vent</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>27576890</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>NSI-Ventilation - Extract Air - Smoke</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
            </clashobjects>
          </clashresult>
          <clashresult name="Clash625" guid="0c1549cb-83c7-4b27-893c-7c647afe9017" href="L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulations vs M_03_Ducts,Duct Fittings,Duct Insulations,Duct Linings_files\cd37510003.jpg" status="new" distance="-0.109">
            <description>Hard</description>
            <resultstatus>New</resultstatus>
            <clashpoint>
              <pos3f x="20589.918" y="-24498.408" z="54.030"/>
            </clashpoint>
            <gridlocation>Xb2-Yb7 : 基礎梁底</gridlocation>
            <createddate>
              <date year="2025" month="7" day="18" hour="16" minute="11" second="27"/>
            </createddate>
            <clashobjects>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>25672497</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>PH - Sanitary - Vent</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>29494667</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>NSI-Ventilation - Extract Air - Smoke</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
            </clashobjects>
          </clashresult>
          <clashresult name="Clash626" guid="51e482da-60bb-48a8-a6de-027c8e06b391" href="L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulations vs M_03_Ducts,Duct Fittings,Duct Insulations,Duct Linings_files\cd37510004.jpg" status="new" distance="-0.107">
            <description>Hard</description>
            <resultstatus>New</resultstatus>
            <clashpoint>
              <pos3f x="20590.030" y="-24497.884" z="62.199"/>
            </clashpoint>
            <gridlocation>Xb2-Yb7 : 基礎梁底</gridlocation>
            <createddate>
              <date year="2025" month="7" day="18" hour="16" minute="11" second="27"/>
            </createddate>
            <clashobjects>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>25672862</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>PH - Sanitary - Vent</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>27615821</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>NSI-Ventilation - Extract Air - Smoke</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
            </clashobjects>
          </clashresult>
          <clashresult name="Clash627" guid="fc8ff739-6840-401f-9b4c-9c36fefcba57" href="L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulations vs M_03_Ducts,Duct Fittings,Duct Insulations,Duct Linings_files\cd37510005.jpg" status="new" distance="-0.098">
            <description>Hard</description>
            <resultstatus>New</resultstatus>
            <clashpoint>
              <pos3f x="20589.920" y="-24498.417" z="61.623"/>
            </clashpoint>
            <gridlocation>Xb2-Yb7 : 基礎梁底</gridlocation>
            <createddate>
              <date year="2025" month="7" day="18" hour="16" minute="11" second="27"/>
            </createddate>
            <clashobjects>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>25672497</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>PH - Sanitary - Vent</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>27615687</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>NSI-Ventilation - Extract Air - Smoke</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
            </clashobjects>
          </clashresult>
          <clashresult name="Clash628" guid="67438b7d-1b1d-4d48-9e90-899caf7c0627" href="L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulations vs M_03_Ducts,Duct Fittings,Duct Insulations,Duct Linings_files\cd37510006.jpg" status="new" distance="-0.098">
            <description>Hard</description>
            <resultstatus>New</resultstatus>
            <clashpoint>
              <pos3f x="20589.920" y="-24498.417" z="61.623"/>
            </clashpoint>
            <gridlocation>Xb2-Yb7 : 基礎梁底</gridlocation>
            <createddate>
              <date year="2025" month="7" day="18" hour="16" minute="11" second="27"/>
            </createddate>
            <clashobjects>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>25672497</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>PH - Sanitary - Vent</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>27615822</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>NSI-Ventilation - Extract Air - Smoke</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
            </clashobjects>
          </clashresult>
          <clashresult name="Clash629" guid="b76edb67-3811-4c96-b23f-1154199e996d" href="L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulations vs M_03_Ducts,Duct Fittings,Duct Insulations,Duct Linings_files\cd37510007.jpg" status="new" distance="-0.094">
            <description>Hard</description>
            <resultstatus>New</resultstatus>
            <clashpoint>
              <pos3f x="20589.920" y="-24498.417" z="61.627"/>
            </clashpoint>
            <gridlocation>Xb2-Yb7 : 基礎梁底</gridlocation>
            <createddate>
              <date year="2025" month="7" day="18" hour="16" minute="11" second="27"/>
            </createddate>
            <clashobjects>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>25672497</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>PH - Sanitary - Vent</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>27615821</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>NSI-Ventilation -
value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>PH - Pipework - Domestic Cold Water Supply - CWS</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>26748320</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>72_ME_Exhaust Air Galvanized Steel Metal</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
            </clashobjects>
          </clashresult>
          <clashresult name="Clash622" guid="3913a346-1a76-45b3-ae17-5efc60ea2ae4" href="L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulations vs M_03_Ducts,Duct Fittings,Duct Insulations,Duct Linings_files\cd37510105.jpg" status="active" distance="-0.002">
            <description>Hard</description>
            <resultstatus>Active</resultstatus>
            <clashpoint>
              <pos3f x="20615.239" y="-24534.122" z="30.136"/>
            </clashpoint>
            <gridlocation>Xb4-Yb14 : 基礎梁底</gridlocation>
            <createddate>
              <date year="2025" month="7" day="9" hour="14" minute="31" second="28"/>
            </createddate>
            <clashobjects>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>25427038</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>Sanitary - Drain</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
              <clashobject>
                <objectattribute>
                  <name>Element ID</name>
                  <value>33091843</value>
                </objectattribute>
                <smarttags>
                  <smarttag>
                    <name>Item Name</name>
                    <value>NSI-Ventilation - Fresh Air</value>
                  </smarttag>
                  <smarttag>
                    <name>Item Type</name>
                    <value>Solid</value>
                  </smarttag>
                </smarttags>
              </clashobject>
            </clashobjects>
          </clashresult>
        </clashresults>
""")

# Generate flat rows out of the root nodes in the tree
rows = [dictify_key_pairs(flatten_xml(row)) for row in tree]
df = pd.DataFrame(rows)
print(df)
# Out:
#          name                                  guid  \
# 0    Clash623  acc45b46-234e-48db-a1ee-3a2d812690c8
# 1    Clash624  3cf6e5d2-f4a8-437d-8759-ad71d0adc5ea
# 2    Clash625  0c1549cb-83c7-4b27-893c-7c647afe9017
# 3    Clash626  51e482da-60bb-48a8-a6de-027c8e06b391
# 4    Clash627  fc8ff739-6840-401f-9b4c-9c36fefcba57
# ..        ...                                   ...
# 100  Clash524  586d3d0f-c296-4d58-943b-2ee7646af5b6
# 101  Clash576  2c88a67d-d2ec-442a-a9c3-98f7dab4cc54
# 102  Clash527  095e4b0a-c83b-4e3a-91e2-b10491af7410
# 103  Clash579  0545f146-c2df-4f4d-939c-c2f4b47fc653
# 104  Clash622  3913a346-1a76-45b3-ae17-5efc60ea2ae4
#
#                                                   href  status distance  \
# 0    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new   -0.126
# 1    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new   -0.122
# 2    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new   -0.109
# ...

# %%
df
# Out:
#          name                                  guid  \
# 0    Clash623  acc45b46-234e-48db-a1ee-3a2d812690c8
# 1    Clash624  3cf6e5d2-f4a8-437d-8759-ad71d0adc5ea
# 2    Clash625  0c1549cb-83c7-4b27-893c-7c647afe9017
# 3    Clash626  51e482da-60bb-48a8-a6de-027c8e06b391
# 4    Clash627  fc8ff739-6840-401f-9b4c-9c36fefcba57
# ..        ...                                   ...
# 100  Clash524  586d3d0f-c296-4d58-943b-2ee7646af5b6
# 101  Clash576  2c88a67d-d2ec-442a-a9c3-98f7dab4cc54
# 102  Clash527  095e4b0a-c83b-4e3a-91e2-b10491af7410
# 103  Clash579  0545f146-c2df-4f4d-939c-c2f4b47fc653
# 104  Clash622  3913a346-1a76-45b3-ae17-5efc60ea2ae4
#
#                                                   href  status distance  \
# 0    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new   -0.126
# 1    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new   -0.122
# 2    L3_PM_P_02_Pipes,Pipe Fittings,Pipe Insulation...     new   -0.109
# ...
